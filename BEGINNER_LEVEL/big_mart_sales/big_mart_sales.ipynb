# %% [markdown]
# # About Practice Problem: Big Mart Sales III
#
# https://datahack.analyticsvidhya.com/contest/practice-problem-big-mart-sales-iii/

# %% [markdown]
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and find out the sales of each product at a particular store.
#
# Using this model, BigMart will try to understand the properties of products and stores which play a key role in increasing sales.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../../hand_made_stuff')
from handmadestuff import fit_predict_report
import statsmodels.formula.api as sm

# Importing data
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')

# # Dropping rows containing NaN values
# loan_df = loan_df.dropna().iloc[:, 1:]

# Display how the data looks
train_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# Counting an amount of missing values
train_df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train_df[train_df.isna().any(axis=1)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# 29             FDC14          NaN          Regular         0.072222
# 30             FDV38       19.250          Low Fat         0.170349
# 33             FDO23       17.850          Low Fat         0.000000
# 36             FDV20          NaN          Regular         0.059512
# 38             FDX10          NaN          Regular         0.123111
# 39             FDB34          NaN          Low Fat         0.026481
# 45             FDM39        6.420               LF         0.089499
# 46             NCP05       19.600          Low Fat         0.000000
# 47             FDV49       10.000          Low Fat         0.025880
# 49             FDS02          NaN          Regular         0.255395
# 53             FDA43       10.895          Low Fat         0.065042
# 54             NCP18       12.150          Low Fat         0.028760
# 56             NCX54        9.195          Low Fat         0.048157
# 59             FDI26          NaN          Low Fat         0.061082
# 61             FDV27        7.970          Regular         0.040071
# 62             FDF09          NaN          Low Fat         0.012090
# 63             FDY40          NaN          Regular         0.150286
# 64             FDY45          NaN          Low Fat         0.026016
# 65             FDC46       17.700               LF         0.195068
# 67             FDZ03       13.650          Regular         0.078946
# 68             DRH37       17.600          Low Fat         0.041701
# ...              ...          ...              ...              ...
# 8463           FDG59          NaN          Low Fat         0.043025
# 8464           FDO56       10.195          Regular         0.045074
# 8465           FDX11       16.000          Regular         0.106969
# 8468           FDB20        7.720          Low Fat         0.052086
# 8469           FDQ45          NaN          Regular         0.019114
# 8471           NCT53        5.400          Low Fat         0.048388
# 8472           NCS41          NaN          Low Fat         0.053185
# 8473           DRI47       14.700          Low Fat         0.035016
# 8474           NCJ42       19.750          Low Fat         0.014330
# 8476           NCO41       12.500          Low Fat         0.018887
# 8477           FDC05       13.100          Regular         0.099343
# 8480           FDQ58          NaN          Low Fat         0.000000
# 8481           FDT56       16.000          Regular         0.115827
# 8483           DRI11        8.260          Low Fat         0.034474
# 8485           DRK37          NaN          Low Fat         0.043792
# 8486           FDR20       20.000          Regular         0.000000
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                          1998         NaN               Tier 3
# 7                          1985      Medium               Tier 3
# 8                          2002         NaN               Tier 2
# 9                          2007         NaN               Tier 2
# 18                         1985      Medium               Tier 3
# 21                         1985      Medium               Tier 3
# 23                         1985       Small               Tier 1
# 25                         2007         NaN               Tier 2
# 28                         1998         NaN               Tier 3
# 29                         1985       Small               Tier 1
# 30                         1998         NaN               Tier 3
# 33                         2002         NaN               Tier 2
# 36                         1985      Medium               Tier 3
# 38                         1985      Medium               Tier 3
# 39                         1985      Medium               Tier 3
# 45                         1998         NaN               Tier 3
# 46                         2002         NaN               Tier 2
# 47                         2002         NaN               Tier 2
# 49                         1985       Small               Tier 1
# 53                         2007         NaN               Tier 2
# 54                         2007         NaN               Tier 2
# 56                         2002         NaN               Tier 2
# 59                         1985       Small               Tier 1
# 61                         2002         NaN               Tier 2
# 62                         1985      Medium               Tier 3
# 63                         1985       Small               Tier 1
# 64                         1985      Medium               Tier 3
# 65                         1998         NaN               Tier 3
# 67                         2002         NaN               Tier 2
# 68                         2002         NaN               Tier 2
# ...                         ...         ...                  ...
# 8463                       1985      Medium               Tier 3
# 8464                       2002         NaN               Tier 2
# 8465                       2002         NaN               Tier 2
# 8468                       2002         NaN               Tier 2
# 8469                       1985       Small               Tier 1
# 8471                       2007         NaN               Tier 2
# 8472                       1985      Medium               Tier 3
# 8473                       1998         NaN               Tier 3
# 8474                       2002         NaN               Tier 2
# 8476                       2002         NaN               Tier 2
# 8477                       2007         NaN               Tier 2
# 8480                       1985       Small               Tier 1
# 8481                       2002         NaN               Tier 2
# 8483                       2002         NaN               Tier 2
# 8485                       1985      Medium               Tier 3
# 8486                       1998         NaN               Tier 3
# 8487                       1985      Medium               Tier 3
# 8488                       1985      Medium               Tier 3
# 8490                       1985       Small               Tier 1
# 8493                       2007         NaN               Tier 2
# 8494                       2007         NaN               Tier 2
# 8496                       2007         NaN               Tier 2
# 8500                       2007         NaN               Tier 2
# 8501                       2007         NaN               Tier 2
# 8502                       2002         NaN               Tier 2
# 8504                       1985      Medium               Tier 3
# 8508                       2002         NaN               Tier 2
# 8509                       1998         NaN               Tier 3
# 8514                       2002         NaN               Tier 2
# 8519                       2002         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 3         Grocery Store           732.3800
# 7     Supermarket Type3          4022.7636
# 8     Supermarket Type1          1076.5986
# 9     Supermarket Type1          4710.5350
# 18    Supermarket Type3          2303.6680
# 21    Supermarket Type3          4064.0432
# 23        Grocery Store           214.3876
# 25    Supermarket Type1           838.9080
# 28        Grocery Store           178.4344
# 29        Grocery Store           125.8362
# 30        Grocery Store           163.7868
# 33    Supermarket Type1          2174.5028
# 36    Supermarket Type3          2797.6916
# 38    Supermarket Type3           388.1614
# 39    Supermarket Type3          2180.4950
# 45        Grocery Store           358.2004
# 46    Supermarket Type1          2428.8384
# 47    Supermarket Type1          5815.0972
# 49        Grocery Store           780.3176
# 53    Supermarket Type1          3121.2704
# 54    Supermarket Type1          4815.0656
# 56    Supermarket Type1          2117.2440
# 59        Grocery Store           892.1720
# 61    Supermarket Type1          1062.6168
# 62    Supermarket Type3           484.7024
# 63        Grocery Store           147.8076
# 64    Supermarket Type3          2543.3560
# 65        Grocery Store           184.4266
# 67    Supermarket Type1          1118.5440
# 68    Supermarket Type1          2302.3364
# ...                 ...                ...
# 8463  Supermarket Type3           810.9444
# 8464  Supermarket Type1           468.7232
# 8465  Supermarket Type1          2726.4510
# 8468  Supermarket Type1           467.3916
# 8469      Grocery Store           367.5216
# 8471  Supermarket Type1          2302.3364
# 8472  Supermarket Type3          1653.8472
# 8473      Grocery Store           431.4384
# 8474  Supermarket Type1          2153.1972
# 8476  Supermarket Type1          1280.9992
# 8477  Supermarket Type1          1970.7680
# 8480      Grocery Store           459.4020
# 8481  Supermarket Type1           695.0952
# 8483  Supermarket Type1          1612.5676
# 8485  Supermarket Type3          6261.8490
# 8486      Grocery Store            45.2744
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8490      Grocery Store           487.3656
# 8493  Supermarket Type1          4727.1800
# 8494  Supermarket Type1          1637.8680
# 8496  Supermarket Type1          3715.1640
# 8500  Supermarket Type1          1907.5170
# 8501  Supermarket Type1          1508.0370
# 8502  Supermarket Type1          3020.0688
# 8504  Supermarket Type3          4138.6128
# 8508  Supermarket Type1          2587.9646
# 8509      Grocery Store           424.7804
# 8514  Supermarket Type1           468.7232
# 8519  Supermarket Type1           549.2850
#
# [3873 rows x 12 columns]

# %%
train_df[train_df.Outlet_Type == 'Grocery Store']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 23             FDC37          NaN          Low Fat         0.057557
# 28             FDE51        5.925          Regular         0.161467
# 29             FDC14          NaN          Regular         0.072222
# 30             FDV38       19.250          Low Fat         0.170349
# 45             FDM39        6.420               LF         0.089499
# 49             FDS02          NaN          Regular         0.255395
# 59             FDI26          NaN          Low Fat         0.061082
# 63             FDY40          NaN          Regular         0.150286
# 65             FDC46       17.700               LF         0.195068
# 77             FDN48          NaN          Low Fat         0.113720
# 83             NCL18          NaN          Low Fat         0.293418
# 90             FDW20       20.750          Low Fat         0.040421
# 95             FDU04          NaN          Low Fat         0.009715
# 108            DRE60          NaN          low fat         0.278974
# 112            FDW39          NaN          Regular         0.064625
# 122            FDB14       20.250          Regular         0.171939
# 133            FDS52        8.890          Low Fat         0.009163
# 139            NCN07       18.500          Low Fat         0.056816
# 174            FDI32       17.700          Low Fat         0.291865
# 175            FDR47       17.850               LF         0.000000
# 177            NCU05       11.800          Low Fat         0.098312
# 178            DRY23          NaN          Regular         0.191014
# 182            NCO17          NaN          Low Fat         0.128478
# 186            FDO08          NaN          Regular         0.094154
# 205            FDF24       15.500          Regular         0.042465
# 208            FDS45          NaN          Regular         0.051644
# 209            FDX40       12.850          Low Fat         0.165694
# 214            NCZ54       14.650          Low Fat         0.000000
# 215            FDE10        6.670          Regular         0.150555
# ...              ...          ...              ...              ...
# 8291           FDU57        8.270          Regular         0.149895
# 8292           FDF56          NaN          Regular         0.209163
# 8296           FDQ08       15.700          Regular         0.031686
# 8318           NCA42        6.965          Low Fat         0.047784
# 8336           FDO08       11.100          Regular         0.090009
# 8337           NCV06          NaN          Low Fat         0.116750
# 49    Grocery Store           780.3176
# 59    Grocery Store           892.1720
# 63    Grocery Store           147.8076
# 65    Grocery Store           184.4266
# 77    Grocery Store           643.1628
# 83    Grocery Store           583.2408
# 90    Grocery Store           369.5190
# 95    Grocery Store           487.3656
# 108   Grocery Store           679.1160
# 112   Grocery Store           176.4370
# 122   Grocery Store           186.4240
# 133   Grocery Store           101.2016
# 139   Grocery Store           263.6568
# 174   Grocery Store           345.5502
# 175   Grocery Store           585.2382
# 177   Grocery Store           161.1236
# 178   Grocery Store            42.6112
# 182   Grocery Store           239.6880
# 186   Grocery Store           657.8104
# 205   Grocery Store           327.5736
# 208   Grocery Store           317.5866
# 209   Grocery Store           231.6984
# 214   Grocery Store           324.9104
# 215   Grocery Store           131.1626
# ...             ...                ...
# 8291  Grocery Store           451.4124
# 8292  Grocery Store           543.2928
# 8296  Grocery Store           122.5072
# 8318  Grocery Store           316.9208
# 8336  Grocery Store           164.4526
# 8337  Grocery Store           193.7478
# 8343  Grocery Store           467.3916
# 8345  Grocery Store           641.1654
# 8353  Grocery Store          1482.0708
# 8358  Grocery Store           121.1756
# 8365  Grocery Store           128.4994
# 8367  Grocery Store           215.7192
# 8371  Grocery Store           185.0924
# 8375  Grocery Store           528.6452
# 8390  Grocery Store           451.4124
# 8399  Grocery Store           284.9624
# 8400  Grocery Store           425.4462
# 8404  Grocery Store           153.1340
# 8405  Grocery Store           124.5046
# 8432  Grocery Store           159.7920
# 8442  Grocery Store            38.6164
# 8449  Grocery Store           571.2564
# 8454  Grocery Store           159.7920
# 8458  Grocery Store           452.7440
# 8469  Grocery Store           367.5216
# 8473  Grocery Store           431.4384
# 8480  Grocery Store           459.4020
# 8486  Grocery Store            45.2744
# 8490  Grocery Store           487.3656
# 8509  Grocery Store           424.7804
#
# [1083 rows x 12 columns]

# %%
train_df[train_df.Outlet_Type == 'Grocery Store'].Outlet_Size.unique()
# Out:
# array([nan, 'Small'], dtype=object)

# %%
train_df.loc[train_df.Outlet_Type == 'Grocery Store', 'Outlet_Size'] = 'Small'

# %%
train_df[train_df.Outlet_Type == 'Grocery Store']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 23             FDC37          NaN          Low Fat         0.057557
# 28             FDE51        5.925          Regular         0.161467
# 29             FDC14          NaN          Regular         0.072222
# 30             FDV38       19.250          Low Fat         0.170349
# 45             FDM39        6.420               LF         0.089499
# 49             FDS02          NaN          Regular         0.255395
# 59             FDI26          NaN          Low Fat         0.061082
# 63             FDY40          NaN          Regular         0.150286
# 65             FDC46       17.700               LF         0.195068
# 77             FDN48          NaN          Low Fat         0.113720
# 83             NCL18          NaN          Low Fat         0.293418
# 90             FDW20       20.750          Low Fat         0.040421
# 95             FDU04          NaN          Low Fat         0.009715
# 108            DRE60          NaN          low fat         0.278974
# 112            FDW39          NaN          Regular         0.064625
# 122            FDB14       20.250          Regular         0.171939
# 133            FDS52        8.890          Low Fat         0.009163
# 139            NCN07       18.500          Low Fat         0.056816
# 174            FDI32       17.700          Low Fat         0.291865
# 175            FDR47       17.850               LF         0.000000
# 177            NCU05       11.800          Low Fat         0.098312
# 8442                       1985       Small               Tier 1
# 8449                       1985       Small               Tier 1
# 8454                       1985       Small               Tier 1
# 8458                       1985       Small               Tier 1
# 8469                       1985       Small               Tier 1
# 8473                       1998       Small               Tier 3
# 8480                       1985       Small               Tier 1
# 8486                       1998       Small               Tier 3
# 8490                       1985       Small               Tier 1
# 8509                       1998       Small               Tier 3
#
#         Outlet_Type  Item_Outlet_Sales
# 3     Grocery Store           732.3800
# 23    Grocery Store           214.3876
# 28    Grocery Store           178.4344
# 29    Grocery Store           125.8362
# 30    Grocery Store           163.7868
# 45    Grocery Store           358.2004
# 49    Grocery Store           780.3176
# 59    Grocery Store           892.1720
# 63    Grocery Store           147.8076
# 65    Grocery Store           184.4266
# 77    Grocery Store           643.1628
# 83    Grocery Store           583.2408
# 90    Grocery Store           369.5190
# 95    Grocery Store           487.3656
# 108   Grocery Store           679.1160
# 112   Grocery Store           176.4370
# 122   Grocery Store           186.4240
# 133   Grocery Store           101.2016
# 139   Grocery Store           263.6568
# 174   Grocery Store           345.5502
# 175   Grocery Store           585.2382
# 177   Grocery Store           161.1236
# 178   Grocery Store            42.6112
# 182   Grocery Store           239.6880
# 186   Grocery Store           657.8104
# 205   Grocery Store           327.5736
# 208   Grocery Store           317.5866
# 209   Grocery Store           231.6984
# 214   Grocery Store           324.9104
# 215   Grocery Store           131.1626
# ...             ...                ...
# 8291  Grocery Store           451.4124
# 8292  Grocery Store           543.2928
# 8296  Grocery Store           122.5072
# 8318  Grocery Store           316.9208
# 8336  Grocery Store           164.4526
# 8337  Grocery Store           193.7478
# 8343  Grocery Store           467.3916
# 8345  Grocery Store           641.1654
# 8353  Grocery Store          1482.0708
# 8358  Grocery Store           121.1756
# 8365  Grocery Store           128.4994
# 8367  Grocery Store           215.7192
# 8371  Grocery Store           185.0924
# 8375  Grocery Store           528.6452
# 8390  Grocery Store           451.4124
# 8399  Grocery Store           284.9624
# 8400  Grocery Store           425.4462
# 8404  Grocery Store           153.1340
# 8405  Grocery Store           124.5046
# 8432  Grocery Store           159.7920
# 8442  Grocery Store            38.6164
# 8449  Grocery Store           571.2564
# 8454  Grocery Store           159.7920
# 8458  Grocery Store           452.7440
# 8469  Grocery Store           367.5216
# 8473  Grocery Store           431.4384
# 8480  Grocery Store           459.4020
# 8486  Grocery Store            45.2744
# 8490  Grocery Store           487.3656
# 8509  Grocery Store           424.7804
#
# [1083 rows x 12 columns]

# %%
train_df[train_df.Outlet_Type == 'Grocery Store'].Outlet_Size.unique()
# Out:
# array(['Small'], dtype=object)

# %%
train_df[train_df.isna().any(axis=1)].shape
# Out:
# (3318, 12)

# %%
(train_df[(train_df.Outlet_Type == 'Supermarket Type1') & (train_df.Outlet_Location_Type == 'Tier 2')]
 .Outlet_Size
 .unique())
# Out:
# array([nan, 'Small'], dtype=object)

# %%
train_df.loc[(train_df.Outlet_Type == 'Supermarket Type1') & (train_df.Outlet_Location_Type == 'Tier 2'), 'Outlet_Size'] = 'Small'

# %%
(train_df[(train_df.Outlet_Type == 'Supermarket Type1') & (train_df.Outlet_Location_Type == 'Tier 2')]
 .Outlet_Size
 .unique())
# Out:
# array(['Small'], dtype=object)

# %%
train_df[train_df.isna().any(axis=1)].shape
# Out:
# (1463, 12)

# %%
(train_df[(train_df.Outlet_Type == 'Supermarket Type1') & (train_df.Outlet_Location_Type == 'Tier 2')]
 .Outlet_Size
 .unique())
# Out:
# array(['Small'], dtype=object)

# %%
(train_df[(train_df.Outlet_Type == 'Supermarket Type2')]
 .Outlet_Size
 .unique())
# Out:
# array(['Medium'], dtype=object)

# %%
(train_df[(train_df.Outlet_Type == 'Supermarket Type3')]
 .Outlet_Size
 .unique())
# Out:
# array(['Medium'], dtype=object)

# %%
train_df[train_df.Item_Weight.isna()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# 36             FDV20          NaN          Regular         0.059512
# 38             FDX10          NaN          Regular         0.123111
# 39             FDB34          NaN          Low Fat         0.026481
# 49             FDS02          NaN          Regular         0.255395
# 59             FDI26          NaN          Low Fat         0.061082
# 62             FDF09          NaN          Low Fat         0.012090
# 63             FDY40          NaN          Regular         0.150286
# 64             FDY45          NaN          Low Fat         0.026016
# 77             FDN48          NaN          Low Fat         0.113720
# 83             NCL18          NaN          Low Fat         0.293418
# 84             FDR12          NaN          Regular         0.031382
# 87             FDQ49          NaN          Regular         0.039058
# 95             FDU04          NaN          Low Fat         0.009715
# 98             NCP18          NaN          Low Fat         0.028460
# 101            FDD10          NaN          Regular         0.045798
# 108            DRE60          NaN          low fat         0.278974
# 112            FDW39          NaN          Regular         0.064625
# 113            FDX34          NaN          Low Fat         0.071637
# 130            FDY25          NaN          Low Fat         0.033810
# 132            NCR53          NaN          Low Fat         0.144338
# 136            FDH35          NaN          Low Fat         0.059957
# 153            DRK12          NaN          Low Fat         0.041683
# 161            FDR07          NaN          Low Fat         0.077367
# 168            NCB30          NaN          Low Fat         0.025579
# 178            DRY23          NaN          Regular         0.191014
# ...              ...          ...              ...              ...
# 8349           FDN15          NaN          Low Fat         0.016653
# 8351           NCE43          NaN               LF         0.102941
# 8353           NCX41          NaN          Low Fat         0.031024
# 8356           FDN45          NaN          Low Fat         0.117531
# 8358           FDK27          NaN          Low Fat         0.015664
# 8362           FDY37          NaN          Regular         0.026440
# 8367           FDA32          NaN               LF         0.052691
# 8372           FDA01          NaN          Regular         0.054115
# 8373           FDX44          NaN          Low Fat         0.042758
# 8375           NCM05          NaN          Low Fat         0.104784
# 8383           NCQ54          NaN          Low Fat         0.012482
# 8390           NCQ05          NaN          Low Fat         0.037829
# 8404           DRH39          NaN          low fat         0.000000
# 8405           FDB09          NaN          Low Fat         0.100493
# 8422           FDD08          NaN          Low Fat         0.035183
# 8435           FDT48          NaN          Low Fat         0.000000
# 8442           FDX40          NaN          Low Fat         0.173324
# 8444           FDO28          NaN          Low Fat         0.071948
# 8449           FDG02          NaN          Low Fat         0.019717
# 8454           NCH54          NaN          Low Fat         0.127234
# 8458           FDX20          NaN          Low Fat         0.074518
# ...                 ...                ...
# 8349  Supermarket Type3          2936.1780
# 8351  Supermarket Type3          4602.0096
# 8353      Grocery Store          1482.0708
# 8356  Supermarket Type3          4026.7584
# 8358      Grocery Store           121.1756
# 8362  Supermarket Type3          2862.9400
# 8367      Grocery Store           215.7192
# 8372  Supermarket Type3          1054.6272
# 8373  Supermarket Type3          2051.9956
# 8375      Grocery Store           528.6452
# 8383  Supermarket Type3          5221.8694
# 8390      Grocery Store           451.4124
# 8404      Grocery Store           153.1340
# 8405      Grocery Store           124.5046
# 8422  Supermarket Type3           417.4566
# 8435  Supermarket Type3           793.6336
# 8442      Grocery Store            38.6164
# 8444  Supermarket Type3           482.0392
# 8449      Grocery Store           571.2564
# 8454      Grocery Store           159.7920
# 8458      Grocery Store           452.7440
# 8463  Supermarket Type3           810.9444
# 8469      Grocery Store           367.5216
# 8472  Supermarket Type3          1653.8472
# 8480      Grocery Store           459.4020
# 8485  Supermarket Type3          6261.8490
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8490      Grocery Store           487.3656
# 8504  Supermarket Type3          4138.6128
#
# [1463 rows x 12 columns]

# %%
train_df.Item_Weight = train_df.Item_Weight.fillna(method='ffill')

# %%
train_df.Item_Fat_Content.nunique()
# Out:
# 5

# %%
train_df.Item_Type.nunique()
# Out:
# 16

# %%
train_df.Outlet_Identifier.nunique()
# Out:
# 10

# %%
train_df.Outlet_Size.nunique()
# Out:
# 3

# %%
train_df.Outlet_Location_Type.nunique()
# Out:
# 3

# %%
train_df.Outlet_Type.nunique()
# Out:
# 4

# %%
train_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
X_train = train_df.iloc[:, 1:-1].values
y_train = train_df.iloc[:, -1].values

# %%
X_train[0]
# Out:
# array([9.3, 'Low Fat', 0.016047301, 'Dairy', 249.8092, 'OUT049', 1999,
#        'Medium', 'Tier 1', 'Supermarket Type1'], dtype=object)

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Encoding the source values
labelencoder_X = LabelEncoder()
categorical_sources = [1, 3, 5, 7, 8, 9]
for i in categorical_sources:
    X_train[:, i] = labelencoder_X.fit_transform(X_train[:, i])

# %%
# Splitting the source values into the categorical and the continuous variables
X_1 = X_train[:, categorical_sources]
X_2 = X_train[:, [item for item in list(range(len(X_train[0]))) if item not in categorical_sources]]

# %%
# Hot encoding the categorical values
onehotencoder = OneHotEncoder()

# %%
categorical_sources.remove(7)

# %%
X_new = X_2
for i in range(len(categorical_sources)):
    # Encoding the fat content column values
    X_1_current_encoded = onehotencoder.fit_transform(X_1[:, i].reshape(-1, 1)).toarray()
    # Avoiding the dummy variable trap
    X_1_current_encoded = X_1_current_encoded[:, :-1]
    X_new = np.concatenate((X_new, X_1_current_encoded), axis = 1)
    # Displaying the data
    print(len(X_new[0]))
# Out:
# 8
# 23
# 32
# 34
# 36

# %%
# Scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_scaled = sc_X.fit_transform(X_new)
# Out:
# F:\STUDY\programming\anaconda\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# F:\STUDY\programming\anaconda\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
sc_y = StandardScaler()
y_scaled = sc_y.fit_transform(y_train.reshape(-1, 1))

# %%
regressor_OLS = sm.OLS(y_scaled, X_scaled).fit()
print(regressor_OLS.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        adjR_before = regressor_OLS.rsquared_adj.astype(float)
        if maxVar > SL:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    temp[:,j] = x[:, j]
                    x = np.delete(x, j, 1)
                    tmp_regressor = sm.OLS(y, x).fit()
                    adjR_after = tmp_regressor.rsquared_adj.astype(float)
                    if (adjR_before >= adjR_after):
                        x_rollback = np.hstack((x, temp[:,[0,j]]))
                        x_rollback = np.delete(x_rollback, j, 1)
                        print (regressor_OLS.summary())
                        return x_rollback
                    else:
                        continue
    regressor_OLS.summary()
    return x

# %%
SL = 0.05
X_modeled = backwardElimination(X_scaled, y_scaled, SL)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     845.5
# Date:                Sun, 25 Nov 2018   Prob (F-statistic):               0.00
# Time:                        00:19:16   Log-Likelihood:                -8559.9
# No. Observations:                8523   AIC:                         1.715e+04
# Df Residuals:                    8510   BIC:                         1.724e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0090      0.007     -1.204      0.229      -0.024       0.006
# x2             0.5677      0.007     79.265      0.000       0.554       0.582
# x3             9.8319      0.301     32.671      0.000       9.242      10.422
# x4             0.0157      0.007      2.185      0.029       0.002       0.030
# x5             0.0096      0.007      1.346      0.178      -0.004       0.024
# x6             2.1931      0.065     33.524      0.000       2.065       2.321
# x7            -1.8090      0.058    -31.397      0.000      -1.922      -1.696
# x8            -3.7267      0.116    -32.024      0.000      -3.955      -3.499
# x9             3.6831      0.118     31.166      0.000       3.451       3.915
# x10            5.3863      0.153     35.099      0.000       5.086       5.687
# x11           -0.7066      0.025    -28.765      0.000      -0.755      -0.658
# x12           -0.0131      0.006     -2.053      0.040      -0.026      -0.001
# x13            0.7145      0.020     35.231      0.000       0.675       0.754
# x14            2.1931      0.065     33.524      0.000       2.065       2.321
# x15           -1.6786      0.055    -30.526      0.000      -1.786      -1.571
# ==============================================================================
# Omnibus:                      963.215   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2302.870
# Skew:                           0.668   Prob(JB):                         0.00
# Kurtosis:                       5.168   Cond. No.                     1.05e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.27e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Splitting the dataset into train and test datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.2,
                                                    random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Predicting the test set results
y_pred = regressor.predict(X_test)

# %%
def calculate_rmse(y_test, y_pred):
    rmse = 0
    y_test, y_pred = y_test.ravel(), y_pred.ravel()
    for i in range(len(y_test)):
        rmse += (y_test[i] - y_pred[i]) ** 2
    return (rmse / len(y_test)) ** (1/2)

# %%
calculate_rmse(y_test, y_pred)
# Out:
# 0.6639372232229135

# %%
# Fitting SVR to the dataset
from sklearn.svm import SVR
regressor_svr = SVR()
regressor_svr.fit(X_train, y_train.ravel())
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# Predicting the test set results
y_pred_svr = regressor_svr.predict(X_test)

# %%
calculate_rmse(y_test, y_pred_svr)
# Out:
# 0.6532421950286379

# %%
# Fitting the Regression Model to the dataset
from sklearn.ensemble import RandomForestRegressor
regressor_rf = RandomForestRegressor(n_estimators = 500, 
                                     random_state = 0)
regressor_rf.fit(X_train, y_train.ravel())
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# Predicting the test set results
y_pred_rf = regressor_rf.predict(X_test)

# %%
calculate_rmse(y_test, y_pred_rf)
# Out:
# 0.6621238929566454
